# %%
import sys
import numpy as np
from cantera import *
from matplotlib.pylab import *
import csv
from SDToolbox import *

#initial values and arrays

P1 = 10.0**5
T1 = 300.0
C1 = 0.04
mech = 'gri30_highT.cti'

P_array = np.linspace(0.5*10**5,100*10**5,50)
P_Bar_array = np.linspace(0.5,100,50)
T_array = np.linspace(240,900,50)
C_array = np.linspace(0.021,0.095,50)

#postshockwave state

P2 = [] #pressure
T2 = [] #temperature
CJspeedo= [] 

x = raw_input('A - variable concentration, B - variable pressure, C - variable temperature ')

#constant pressure and temperature, variable concenctration

if x == 'A':
 for C1 in C_array:
  a = 4.76*C1/(1-C1)
  q ='O2:1.,N2:3.76,C3H8:' + str(a)
  [cj_speed,R2] = CJspeed(P1, T1, q, mech, 0)
  gas = PostShock_eq(cj_speed, P1, T1, q, mech)
  P2.append(gas.P*0.00001)
  T2.append(gas.T)
  CJspeedo.append(cj_speed)
    
 #plotting the results

 plt.figure()
 plt.plot(C_array*100, T2)
 plt.xlabel('Initial concentrarion [%]')
 plt.ylabel('Temperature [K]')
 plt.title('Post shockwave temperature')

 plt.figure()
 plt.plot(C_array*100, P2)
 plt.xlabel('Initial concentrarion [%]')
 plt.ylabel('Pressure [bar]')
 plt.title('Post shockwave pressure')

 plt.figure()
 plt.plot(C_array*100, CJspeedo)
 plt.xlabel('Initial concentrarion [%]')
 plt.ylabel('CJ speed [m/s]')
 plt.title('CJ speed')

 plt.show()

#constant concenctration and temperature, variable pressure

elif x == 'B':
 for P1 in P_array:
  a = 4.76*C1/(1-C1)
  q ='O2:1.,N2:3.76,C3H8:' + str(a)
  [cj_speed, R2] = CJspeed(P1, T1, q, mech, 0)
  gas = PostShock_eq(cj_speed, P1, T1, q, mech)
  T2.append(gas.T)
  P2.append(gas.P*0.00001)
  CJspeedo.append(cj_speed)
    
 #plotting the results
 plt.figure()
 plt.plot(P_Bar_array, T2)
 plt.xlabel('Initial pressure [bar]')
 plt.ylabel('Temperature [K]')
 plt.title('Post shockwave temperature') 

 plt.figure()
 plt.plot(P_Bar_array, P2)
 plt.xlabel('Initial pressure [bar]')
 plt.ylabel('Pressure [bar]')
 plt.title('Post shockwave pressure')

 plt.figure()
 plt.plot(P_Bar_array, CJspeedo)
 plt.xlabel('Initial pressure [bar]')
 plt.ylabel('CJ speed [m/s]')
 plt.title('CJ speed')

 plt.show()
    
#constant pressure and concenctration, variable temperature

elif x == 'C':
 for T1 in T_array:
  a = 4.76*C1/(1-C1)
  q ='O2:1., N2:3.76, C3H8:' + str(a)
  [cj_speed,R2] = CJspeed(P1, T1, q, mech, 0)
  gas = PostShock_eq(cj_speed, P1, T1, q, mech)
  T2.append(gas.T)
  P2.append(gas.P*0.00001)
  CJspeedo.append(cj_speed)
    
 #plotting the results
 plt.figure()
 plt.plot(T_array, T2)
 plt.xlabel('Initial temperature [K]')
 plt.ylabel('Temperature [K]')
 plt.title('Post shockwave temperature')

 plt.figure()
 plt.plot(T_array, P2)
 plt.xlabel('Initial temperature [K]')
 plt.ylabel('Pressure [bar]')
 plt.title('Post shockwave pressure')

 plt.figure()
 plt.plot(T_array, CJspeedo)
 plt.xlabel('Initial temperature [K]')
 plt.ylabel('CJ speed [m/s]')
 plt.title('CJ speed')

 plt.show()
# Out:
# A - variable concentration, B - variable pressure, C - variable temperatureB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-7d0d58bd111e> in <module>()
#      78
#      79  plt.figure()
# ---> 80  plt.plot(P_array, P2)
#      81  plt.xlabel('Initial pressure [Pa]')
#      82  plt.ylabel('Pressure [Pa]')
#
# C:\Users\X240\AppData\Local\conda\conda\envs\mkwsSDT\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# C:\Users\X240\AppData\Local\conda\conda\envs\mkwsSDT\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Users\X240\AppData\Local\conda\conda\envs\mkwsSDT\lib\site-packages\matplotlib\axes\_axes.pyc in plot(self, *args, **kwargs)
#    1525         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1526
# -> 1527         for line in self._get_lines(*args, **kwargs):
#    1528             self.add_line(line)
#    1529             lines.append(line)
#
# C:\Users\X240\AppData\Local\conda\conda\envs\mkwsSDT\lib\site-packages\matplotlib\axes\_base.pyc in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# C:\Users\X240\AppData\Local\conda\conda\envs\mkwsSDT\lib\site-packages\matplotlib\axes\_base.pyc in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# C:\Users\X240\AppData\Local\conda\conda\envs\mkwsSDT\lib\site-packages\matplotlib\axes\_base.pyc in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (50L,) and (0L,)
